# %% [markdown]
# # Getting Started with Turtlesim
# Source: http://wiki.ros.org/turtlesim
#
# The `turtlesim` is already installed and the `roscore` is started. Therefore we can directly run turtlesim demo.

# %% [markdown]
# ## Run Turlesim
#
# 1. Open the `Xpra Desktop`
# 1. Open a new `terminal` and execute:
#
#     ```bash
#     rosrun turtlesim turtlesim_node
#     ```
#
#
# You should see the TurtleSim window open in the Xpra Desktop

# %% [markdown]
# ## Check running ROS node
# You can also run the following commands in a new terminal.

# %%
# !rosnode list
# Out:
# /ros_board
# /rosapi
# /rosbridge_websocket
# /rosout
# /roswww
# /tf2_web_republisher
# /turtlesim

# %%
# !rosnode info /turtlesim
# Out:
# --------------------------------------------------------------------------------
# Node [/turtlesim]
# Publications:
#  * /rosout [rosgraph_msgs/Log]
#  * /turtle1/color_sensor [turtlesim/Color]
#  * /turtle1/pose [turtlesim/Pose]
#
# Subscriptions:
#  * /turtle1/cmd_vel [unknown type]
#
# Services:
#  * /clear
#  * /kill
#  * /reset
#  * /spawn
#  * /turtle1/set_pen
#  * /turtle1/teleport_absolute
#  * /turtle1/teleport_relative
#  * /turtlesim/get_loggers
#  * /turtlesim/set_logger_level
#
#
# contacting node http://jupyter-intel4coro-2dbinder-2dtemplate-2dtkpfd0r1:40629/ ...
# Pid: 1436
# Connections:
#  * topic: /rosout
#     * to: /rosout
#     * direction: outbound (52857 - 10.1.202.142:43136) [16]
#     * transport: TCPROS

# %% [markdown]
# ## Publish ROS messages
# Publish messages to topic `/turtle1/cmd_vel` to control the turtle

# %%
from geometry_msgs.msg import Twist, Vector3
import rospy

rospy.init_node('turtlesim_notebook')
cmd_vel_pub = rospy.Publisher('/turtle1/cmd_vel', Twist, queue_size=5)
cmd_vel_msg = Twist()

# %%
# Run in circle
cmd_vel_msg.linear.x = 10
cmd_vel_msg.angular.z = 5
cmd_vel_pub.publish(cmd_vel_msg)

# %% [markdown]
# ### GUI tool `rqt_graph`

# %%
# !rqt_graph
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-jovyan'
# ^C
